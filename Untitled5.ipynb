# %% [markdown]
# <a href="https://colab.research.google.com/github/p1tuo/20201021/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #資料來源:拿公投統計資料學 pandas
# https://newtoypia.blogspot.com/2018/12/pandas.html

# %% [markdown]
# #下載完資料

# %%
# !wget https://raw.githubusercontent.com/MyDearGreatTeacher/AI_and_security_2020/master/referendum2.csv
# Out:
# --2020-10-28 01:31:11--  https://raw.githubusercontent.com/MyDearGreatTeacher/AI_and_security_2020/master/referendum2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 219621 (214K) [text/plain]
# Saving to: ‘referendum2.csv’
#
# referendum2.csv     100%[===================>] 214.47K  --.-KB/s    in 0.02s
#
# 2020-10-28 01:31:12 (13.2 MB/s) - ‘referendum2.csv’ saved [219621/219621]

# %% [markdown]
# #讀取已處理好的資料

# %%
cat referendum2.csv

# %% [markdown]
# #使用pd.read_csv讀取資料

# %%
import pandas as pd
refm = pd.read_csv('referendum2.csv')

# %%
refm
# Out:
#        案件   縣市 鄉鎮市區     同意票數    不同意票數      有效票數    無效票數       投票數     投票權人數
# 0     c07   全國  NaN  7955753  2109157  10064910  715140  10780050  19757067
# 1     c07  南投縣  NaN   187162    41641    228803   15881    244684    427089
# 2     c07  南投縣  中寮鄉     5701     1272      6973     633      7606     13181
# 3     c07  南投縣  仁愛鄉     5087     1090      6177     467      6644     12589
# 4     c07  南投縣  信義鄉     5246     1259      6505     961      7466     13299
# ...   ...  ...  ...      ...      ...       ...     ...       ...       ...
# 3905  c16  高雄市  阿蓮區     6890     5125     12015    1066     13081     24534
# 3906  c16  高雄市  鳥松區    12625     9306     21931    1688     23619     39191
# 3907  c16  高雄市  鳳山區    99747    64662    164409   12511    176920    300510
# 3908  c16  高雄市  鹽埕區     6495     4957     11452     718     12170     21617
# 3909  c16  高雄市  鼓山區    38075    24959     63034    4429     67463    114979
#
# [3910 rows x 9 columns]

# %%
refm['同意票數']
# Out:
# 0       7955753
# 1        187162
# 2          5701
# 3          5087
# 4          5246
#          ...
# 3905       6890
# 3906      12625
# 3907      99747
# 3908       6495
# 3909      38075
# Name: 同意票數, Length: 3910, dtype: int64

# %% [markdown]
# #驗證投票
# ------
# 同意票+不同意票= =有效票
# -----
# 有效票+無效票=投票數

# %%
x=refm['同意票數']+refm['不同意票數']-refm['有效票數']
x.describe()
# Out:
# count    3910.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# dtype: float64

# %%
x=refm['有效票數']+refm['無效票數']-refm['投票數']
x.describe()
# Out:
# count    3910.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# dtype: float64

# %% [markdown]
# #計算 「贊成比例」
# ```
# 計算「贊成比例」並且把「鄉鎮市區」冠上縣市名稱。
# 只留下「案件」、「鄉鎮市區」、「贊成比例」。
# ```

# %%
refm2 = refm[~ refm['鄉鎮市區'].isnull()]
refm2
# Out:
#        案件   縣市 鄉鎮市區   同意票數  不同意票數    有效票數   無效票數     投票數   投票權人數
# 2     c07  南投縣  中寮鄉   5701   1272    6973    633    7606   13181
# 3     c07  南投縣  仁愛鄉   5087   1090    6177    467    6644   12589
# 4     c07  南投縣  信義鄉   5246   1259    6505    961    7466   13299
# 5     c07  南投縣  南投市  39753   8588   48341   2677   51018   84328
# 6     c07  南投縣  名間鄉  14946   3387   18333   1622   19955   33408
# ...   ...  ...  ...    ...    ...     ...    ...     ...     ...
# 3905  c16  高雄市  阿蓮區   6890   5125   12015   1066   13081   24534
# 3906  c16  高雄市  鳥松區  12625   9306   21931   1688   23619   39191
# 3907  c16  高雄市  鳳山區  99747  64662  164409  12511  176920  300510
# 3908  c16  高雄市  鹽埕區   6495   4957   11452    718   12170   21617
# 3909  c16  高雄市  鼓山區  38075  24959   63034   4429   67463  114979
#
# [3680 rows x 9 columns]

# %%
refm3 = refm.dropna(subset=['鄉鎮市區'])
refm3
# Out:
#        案件   縣市 鄉鎮市區   同意票數  不同意票數    有效票數   無效票數     投票數   投票權人數
# 2     c07  南投縣  中寮鄉   5701   1272    6973    633    7606   13181
# 3     c07  南投縣  仁愛鄉   5087   1090    6177    467    6644   12589
# 4     c07  南投縣  信義鄉   5246   1259    6505    961    7466   13299
# 5     c07  南投縣  南投市  39753   8588   48341   2677   51018   84328
# 6     c07  南投縣  名間鄉  14946   3387   18333   1622   19955   33408
# ...   ...  ...  ...    ...    ...     ...    ...     ...     ...
# 3905  c16  高雄市  阿蓮區   6890   5125   12015   1066   13081   24534
# 3906  c16  高雄市  鳥松區  12625   9306   21931   1688   23619   39191
# 3907  c16  高雄市  鳳山區  99747  64662  164409  12511  176920  300510
# 3908  c16  高雄市  鹽埕區   6495   4957   11452    718   12170   21617
# 3909  c16  高雄市  鼓山區  38075  24959   63034   4429   67463  114979
#
# [3680 rows x 9 columns]

# %%
refm = refm3
refm['贊成比例'] = refm['同意票數']/refm['投票數']
refm['鄉鎮市區'] = refm['縣市'] + refm['鄉鎮市區']
refm2 = refm.drop(columns=['縣市', '同意票數', '不同意票數', '有效票數', '無效票數', '投票數', '投票權人數'])
refm3 = refm[['案件', '鄉鎮市區', '贊成比例']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '同意票數'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-52486b2dd08b> in <module>()
#       1 refm = refm3
# ----> 2 refm['贊成比例'] = refm['同意票數']/refm['投票數']
#       3 refm['鄉鎮市區'] = refm['縣市'] + refm['鄉鎮市區']
#       4 refm2 = refm.drop(columns=['縣市', '同意票數', '不同意票數', '有效票數', '無效票數', '投票數', '投票權人數'])
#       5 refm3 = refm[['案件', '鄉鎮市區', '贊成比例']]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: '同意票數'

# %%
refm
# Out:
#        案件       鄉鎮市區      贊成比例
# 2     c07  南投縣南投縣中寮鄉  0.749540
# 3     c07  南投縣南投縣仁愛鄉  0.765653
# 4     c07  南投縣南投縣信義鄉  0.702652
# 5     c07  南投縣南投縣南投市  0.779196
# 6     c07  南投縣南投縣名間鄉  0.748985
# ...   ...        ...       ...
# 3905  c16  高雄市高雄市阿蓮區  0.526718
# 3906  c16  高雄市高雄市鳥松區  0.534527
# 3907  c16  高雄市高雄市鳳山區  0.563797
# 3908  c16  高雄市高雄市鹽埕區  0.533689
# 3909  c16  高雄市高雄市鼓山區  0.564383
#
# [3680 rows x 3 columns]

# %%
refm
# Out:
#        案件       鄉鎮市區      贊成比例
# 2     c07  南投縣南投縣中寮鄉  0.749540
# 3     c07  南投縣南投縣仁愛鄉  0.765653
# 4     c07  南投縣南投縣信義鄉  0.702652
# 5     c07  南投縣南投縣南投市  0.779196
# 6     c07  南投縣南投縣名間鄉  0.748985
# ...   ...        ...       ...
# 3905  c16  高雄市高雄市阿蓮區  0.526718
# 3906  c16  高雄市高雄市鳥松區  0.534527
# 3907  c16  高雄市高雄市鳳山區  0.563797
# 3908  c16  高雄市高雄市鹽埕區  0.533689
# 3909  c16  高雄市高雄市鼓山區  0.564383
#
# [3680 rows x 3 columns]

# %%
refm = refm3
x07 = refm[refm['案件']=='c07'][['鄉鎮市區','贊成比例']]
x08 = refm[refm['案件']=='c08'][['鄉鎮市區','贊成比例']]
tmp = pd.concat([x07.set_index('鄉鎮市區'), x08.set_index('鄉鎮市區')], axis=1, sort=True)
tmp.columns = ['c07', 'c08']
refm
# Out:
#        案件       鄉鎮市區      贊成比例
# 2     c07  南投縣南投縣中寮鄉  0.749540
# 3     c07  南投縣南投縣仁愛鄉  0.765653
# 4     c07  南投縣南投縣信義鄉  0.702652
# 5     c07  南投縣南投縣南投市  0.779196
# 6     c07  南投縣南投縣名間鄉  0.748985
# ...   ...        ...       ...
# 3905  c16  高雄市高雄市阿蓮區  0.526718
# 3906  c16  高雄市高雄市鳥松區  0.534527
# 3907  c16  高雄市高雄市鳳山區  0.563797
# 3908  c16  高雄市高雄市鹽埕區  0.533689
# 3909  c16  高雄市高雄市鼓山區  0.564383
#
# [3680 rows x 3 columns]

# %%
summary = refm[refm['案件']=='c07'][['鄉鎮市區','贊成比例']].set_index('鄉鎮市區')
cnames = refm['案件'].unique()
for c in cnames[1:] :
    tmp = refm[refm['案件']==c][['鄉鎮市區','贊成比例']]
    summary = pd.concat([summary, tmp.set_index('鄉鎮市區')], axis=1, sort=True)

summary.columns = cnames
